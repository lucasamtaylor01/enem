# %%
import pandas as pd
from pathlib import Path
import plotly.express as px

# %%
data_dir = Path("data")
INDIR = Path("../data/data_model")

# %%
df = pd.read_csv(INDIR / "ANALISE_NOTAS_ENEM_MUNICIPIOS_BRASIL_CLUSTERS_2024.csv", sep=",")

# %%
df.head()
# Out:
#   NO_MUNICIPIO_PROVA  UF  QTD_PARTICIPANTES  NU_NOTA_CN_MEDIA  \
# 0         ABAETETUBA  PA               4890        461.314479
# 1             ABAETÉ  MG                546        492.137179
# 2       ABREU E LIMA  PE               1810        473.122486
# 3            ACARAPE  CE                410        464.850244
# 4             ACARAÚ  CE               1141        473.460035
#
#    NU_NOTA_CH_MEDIA  NU_NOTA_LC_MEDIA  NU_NOTA_MT_MEDIA  \
# 0        466.065501        483.305317        473.035583
# 1        523.886996        539.278022        547.032601
# 2        493.848674        513.249448        493.806796
# 3        480.734878        500.530488        501.268537
# 4        479.478002        499.146012        521.760649
#
#    NU_NOTA_REDACAO_MEDIA  RENDA_FAMILIAR_SM_MEDIA  CLUSTER
# 0             586.355828                 1.253781        0
# 1             667.326007                 2.451439        2
# 2             589.690608                 1.359065        1
# ...

# %%
df_cluster_2 = df[df["CLUSTER"] == 2]
df_cluster_2 = df_cluster_2.sort_values(by="RENDA_FAMILIAR_SM_MEDIA", ascending=True)
df_cluster_2.head(10)
# Out:
#      NO_MUNICIPIO_PROVA  UF  QTD_PARTICIPANTES  NU_NOTA_CN_MEDIA  \
# 1575            TAVARES  PB                440        478.543409
# 477                CRUZ  CE                444        488.088514
# 1337             RUSSAS  CE               1165        492.106524
# 697               IRECÊ  BA               2285        490.374267
# 870   LIMOEIRO DO NORTE  CE               1810        497.044862
# 163            BARBALHA  CE               1683        494.139869
# 347           CAPELINHA  MG                931        485.256928
# 473               CRATO  CE               3170        494.027666
# 962       MIMOSO DO SUL  ES                384        495.646875
# 533             ERVÁLIA  MG                349        497.609742
#
#       NU_NOTA_CH_MEDIA  NU_NOTA_LC_MEDIA  NU_NOTA_MT_MEDIA  \
# 1575        509.367955        523.642273        543.402955
# 477         508.054730        518.277252        552.251577
# 1337        516.177082        524.132532        546.014592
# ...
